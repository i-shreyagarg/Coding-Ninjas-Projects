# %%
import numpy as np
import pandas as pd

# %%
train_data=np.genfromtxt("0000000000002329_training_diabetes_x_y_train.csv",delimiter=",")
test_data=np.genfromtxt("0000000000002329_test_diabetes_x_test.csv",delimiter=",")

# %%
print(type(train_data),type(test_data))
df=pd.DataFrame(train_data)
df.columns=["age","sex","bmi","bp","s1","s2","s3","s4","s5","s6","Y"]
df
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
#           age       sex       bmi        bp        s1        s2        s3  \
# 0   -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
# 1   -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 2    0.001751 -0.044642 -0.070875 -0.022885 -0.001569 -0.001001  0.026550
# 3    0.048974  0.050680  0.081097  0.021872  0.043837  0.064134 -0.054446
# 4    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.012648 -0.044642 -0.020218 -0.015999  0.012191  0.021233 -0.076536
# 327  0.019913 -0.044642 -0.057941 -0.057314 -0.001569 -0.012587  0.074412
# 328  0.023546 -0.044642  0.070319  0.025315 -0.034592 -0.014466 -0.032356
# 329  0.016281  0.050680  0.072474  0.076958 -0.008449  0.005575 -0.006584
# 330 -0.009147  0.050680 -0.030996 -0.026328 -0.011201 -0.001001 -0.021311
#
# ...

# %%
df.describe()
# Out:
#               age         sex         bmi          bp          s1          s2  \
# count  331.000000  331.000000  331.000000  331.000000  331.000000  331.000000
# mean    -0.000214   -0.000293    0.000053   -0.001045   -0.001423   -0.001220
# std      0.047207    0.047618    0.048627    0.047621    0.047371    0.046936
# min     -0.107226   -0.044642   -0.090275   -0.102071   -0.126781   -0.115613
# 25%     -0.034575   -0.044642   -0.035307   -0.036656   -0.035968   -0.029967
# 50%      0.005383   -0.044642   -0.008362   -0.005671   -0.004321   -0.004445
# 75%      0.038076    0.050680    0.030979    0.032775    0.027326    0.028905
# max      0.110727    0.050680    0.170555    0.132044    0.153914    0.198788
#
#                s3          s4          s5          s6           Y
# count  331.000000  331.000000  331.000000  331.000000  331.000000
# mean     0.000440   -0.001473   -0.001594    0.000099  149.722054
# std      0.047303    0.046591    0.048088    0.047263   76.796907
# ...

# %%
X=df[["age","sex","bmi","bp","s1","s2","s3","s4","s5","s6"]]
Y=df.Y
print(X.shape,Y.shape)
# Out:
# (331, 10) (331,)

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(X,Y)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (248, 10) (83, 10) (248,) (83,)

# %%
from sklearn.linear_model import LinearRegression
alg=LinearRegression()

# %%
alg.fit(x_train,y_train)
y_predic=alg.predict(x_test)
print(np.around(y_predic,decimals=5))
# Out:
# [ 96.99843  89.7854  133.76954 116.18437  67.45282 140.95919 148.76011
#  159.68725 148.02613 246.61666 233.78183 139.73355 166.20471  55.60433
#   90.9538  156.43707 169.18904 188.52644  71.71945 122.91509 155.73504
#  183.34049 187.46285 121.98573 174.1119   81.69018 182.18662 207.53546
#  191.99239 120.3497  127.09846 159.38781  62.78159 164.28513 235.65198
#  153.81815  96.5818  131.00672 199.28956 173.32327  51.79449  98.6655
#   69.21072 186.93952  61.98863 175.88209 215.10389 106.76552 234.0153
#  112.472   141.19216 128.84646  58.83718 163.73021 133.17709 143.39705
#  126.99905 119.74995  94.75618 203.36137 184.48893 250.14552 108.22175
#  228.9143  261.95525 137.29639 213.07158 151.69754 104.1388  108.50249
#  118.69341 177.31579 154.68531 159.25469 178.3039  168.0949   79.4889
#  101.9944  222.20939 205.76754 135.51579  85.12317 118.19772]

# %%
import matplotlib.pyplot as plt
plt.scatter(y_predict,y_test)
plt.axis([50,300,50,300])
plt.show()

# %%
df_test=pd.DataFrame(test_data)
df_test.columns=["age","sex","bmi","bp","s1","s2","s3","s4","s5","s6"]
df_test
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.023546  0.050680 -0.037463 -0.046985 -0.091006 -0.075530 -0.032356
# 1   -0.078165 -0.044642 -0.073030 -0.057314 -0.084126 -0.074277 -0.024993
# 2   -0.030942  0.050680  0.001339 -0.005671  0.064477  0.049416 -0.047082
# 3   -0.005515  0.050680  0.001339 -0.084857 -0.011201 -0.016658  0.048640
# 4   -0.020045 -0.044642 -0.084886 -0.026328 -0.035968 -0.034194  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 106  0.009016  0.050680  0.069241  0.059744  0.017694 -0.023234 -0.047082
# 107  0.005383 -0.044642  0.049840  0.097616 -0.015328 -0.016345 -0.006584
# 108  0.009016 -0.044642 -0.012673  0.028758 -0.018080 -0.005072 -0.047082
# 109  0.019913 -0.044642 -0.034229  0.055153  0.067229  0.074155 -0.006584
# 110  0.016281  0.050680  0.009961 -0.043542 -0.096510 -0.094632 -0.039719
#
#            s4        s5        s6
# 0   -0.039493 -0.030751 -0.013504
# ...

# %%
y_predic_test=alg.predict(df_test)
print(np.around(y_predic_test,decimals=5))
test_data=np.savetxt("predictions.csv",y_predic_test,delimiter=",")
# Out:
# [106.53495 107.49854 173.90688  73.11037  60.61551 102.25616 152.27254
#   38.14677 113.00453 160.02946 131.94471  98.49372 141.65351 145.4321
#  157.77647 171.58754 107.78035 103.90072  91.45061 168.49377 163.31259
#  103.74138 252.09148 146.06823 210.49822 164.63396 208.03059  69.09792
#  191.11986 206.60005 218.06039 172.82368 120.68179 179.9063   77.02007
#   58.50625 113.97589 161.1605  152.90514 194.11498 117.85316 152.47964
#   89.8719  112.62176 136.95244 150.16351  83.42563  74.98742 129.86219
#  265.23614 213.89361 245.27594 171.21853 185.11783 169.41429 206.24649
#  225.93894 171.66652 178.41976 107.97184 277.2522   94.04921 288.16085
#  127.96905  75.47225 185.05099 147.00618 160.26713  45.63678 253.02643
#  209.40886  82.81823 222.88151 191.04441 177.79313 163.51756 193.66562
#  106.9846  201.94764 243.56282 124.00363 120.60441 141.03257 203.87167
#  145.90171 139.48213 160.41953 112.90627 139.80886 121.7322  205.13659
# ...
